# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
BATCH_SIZE = 32 # standard batch size
IMAGE_SIZE = 256
CHANNELS= 3
EPOCHS= 10

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    seed=123,
    shuffle=True,
    image_size=(256, 256),
    batch_size=32
)
class_names = dataset.class_names
class_names
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# Found 4500 files belonging to 3 classes.
# (32, 256, 256, 3)
# [1 1 2 2 2 0 2 1 2 2 2 2 1 1 2 1 1 1 0 1 1 0 0 1 0 1 1 2 0 1 1 1]

# %%
plt.figure(figsize=(15, 15))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
train_size = 0.8
train_ds = dataset.take(112)
est_ds = dataset.skip(112)
val_size=0.1
len(dataset)*val_size
val_ds = test_ds.take(14)
len(val_ds)
test_ds = test_ds.skip(14)
len(test_ds)
# Out:
# 1

# %%
#check it
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandoFmRotation(0.2),
])
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32, kernel_size = (3,3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(112,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(112,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(112, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(112, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(112, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(112, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d_12 (Conv2D)          (32, 254, 254, 32)        896
#
#  max_pooling2d_12 (MaxPoolin  (32, 127, 127, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (32, 125, 125, 112)       32368
#
#  max_pooling2d_13 (MaxPoolin  (32, 62, 62, 112)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (32, 60, 60, 112)         113008
#
#  max_pooling2d_14 (MaxPoolin  (32, 30, 30, 112)        0
#  g2D)
#
#  conv2d_15 (Conv2D)          (32, 28, 28, 112)         113008
#
#  max_pooling2d_15 (MaxPoolin  (32, 14, 14, 112)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (32, 12, 12, 112)         113008
#
#  max_pooling2d_16 (MaxPoolin  (32, 6, 6, 112)          0
#  g2D)
#
#  conv2d_17 (Conv2D)          (32, 4, 4, 112)           113008
#
#  max_pooling2d_17 (MaxPoolin  (32, 2, 2, 112)          0
#  g2D)
#
#  flatten_2 (Flatten)         (32, 448)                 0
#
#  dense_4 (Dense)             (32, 112)                 50288
#
#  dense_5 (Dense)             (32, 3)                   339
#
# =================================================================
# Total params: 535,923
# Trainable params: 535,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=10,
)
# Out:
# Epoch 1/10
# 112/112 [==============================] - 257s 2s/step - loss: 0.9860 - accuracy: 0.5008 - val_loss: 0.7227 - val_accuracy: 0.6652
# Epoch 2/10
# 112/112 [==============================] - 219s 2s/step - loss: 0.5904 - accuracy: 0.7310 - val_loss: 0.6205 - val_accuracy: 0.7768
# Epoch 3/10
# 112/112 [==============================] - 216s 2s/step - loss: 0.4701 - accuracy: 0.7907 - val_loss: 0.4955 - val_accuracy: 0.7857
# Epoch 4/10
# 112/112 [==============================] - 215s 2s/step - loss: 0.3515 - accuracy: 0.8552 - val_loss: 0.4662 - val_accuracy: 0.8438
# Epoch 5/10
# 112/112 [==============================] - 213s 2s/step - loss: 0.3466 - accuracy: 0.8577 - val_loss: 0.4755 - val_accuracy: 0.8214
# Epoch 6/10
# 112/112 [==============================] - 207s 2s/step - loss: 0.3052 - accuracy: 0.8750 - val_loss: 0.3144 - val_accuracy: 0.8772
# Epoch 7/10
# 112/112 [==============================] - 215s 2s/step - loss: 0.4468 - accuracy: 0.8329 - val_loss: 0.4444 - val_accuracy: 0.8170
# Epoch 8/10
# 112/112 [==============================] - 221s 2s/step - loss: 0.3234 - accuracy: 0.8664 - val_loss: 0.4068 - val_accuracy: 0.8415
# Epoch 9/10
# 112/112 [==============================] - 206s 2s/step - loss: 0.2724 - accuracy: 0.8873 - val_loss: 0.2857 - val_accuracy: 0.8795
# Epoch 10/10
# 112/112 [==============================] - 206s 2s/step - loss: 0.2848 - accuracy: 0.8814 - val_loss: 0.3431 - val_accuracy: 0.8661

# %%
sc = model.evaluate(test_ds)
# Out:
# 1/1 [==============================] - 15s 15s/step - loss: 0.4619 - accuracy: 0.8500

# %%
#run prediction
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Tomato_healthy
# predicted label: Tomato_healthy

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
